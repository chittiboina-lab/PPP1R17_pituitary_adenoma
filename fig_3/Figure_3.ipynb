# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../../methylation_analysis/results/beta_sig_01.csv', sep = ',',index_col=0)
names = ["CD 1", "CD 2", "CD 3", "CD 4", "CD 5", "CD 6", "Normal 1", "Normal 2", "Normal 3", "Normal 4", "Normal 5", "Normal 6", "Normal 7", "Normal 8", "Normal 9", "Normal 10", "Normal 11"]
data.columns = names
# data.dropna()
data
# Out:
#                 CD 1      CD 2      CD 3      CD 4      CD 5      CD 6  \
# cg07147033  0.164190  0.156483  0.145592  0.156200  0.131358  0.201227
# cg00850868  0.496730  0.475324  0.374391  0.398007  0.486575  0.252980
# cg04944454  0.855315  0.873581  0.833713  0.822335  0.508173  0.777884
# cg08751438  0.623241  0.520809  0.319494  0.598541  0.595024  0.501502
# cg21256706  0.068677  0.055114  0.137904  0.059124  0.270021  0.350343
# ...              ...       ...       ...       ...       ...       ...
# cg04847526  0.885363  0.800898  0.819076  0.804952  0.682940  0.631904
# cg01017780  0.849672  0.852820  0.793930  0.851266  0.784237  0.701461
# cg18438461  0.329129  0.238383  0.285041  0.362512  0.402207  0.168319
# cg26705553  0.049900  0.038603  0.062500  0.048037  0.088035  0.090291
# cg03571927  0.049773  0.048105  0.052042  0.048478  0.047771  0.076850
#
#             Normal 1  Normal 2  Normal 3  Normal 4  Normal 5  Normal 6  \
# ...

# %%
data = data.dropna()
data = data.transpose()
data
# Out:
#            cg07147033  cg00850868  cg04944454  cg08751438  cg21256706  \
# CD 1         0.164190    0.496730    0.855315    0.623241    0.068677
# CD 2         0.156483    0.475324    0.873581    0.520809    0.055114
# CD 3         0.145592    0.374391    0.833713    0.319494    0.137904
# CD 4         0.156200    0.398007    0.822335    0.598541    0.059124
# CD 5         0.131358    0.486575    0.508173    0.595024    0.270021
# CD 6         0.201227    0.252980    0.777884    0.501502    0.350343
# Normal 1     0.237201    0.611806    0.903268    0.699973    0.026831
# Normal 2     0.228486    0.672953    0.913110    0.694085    0.038592
# Normal 3     0.218833    0.676222    0.931208    0.714052    0.020193
# Normal 4     0.280138    0.677092    0.886937    0.732672    0.047459
# Normal 5     0.365990    0.674234    0.930251    0.801552    0.060603
# Normal 6     0.283545    0.525788    0.882978    0.727444    0.042883
# ...

# %%
fig = sns.clustermap(data, 
               z_score = 1,
               row_cluster=True, col_cluster=True,
               cmap='icefire',
               figsize=(14,6),
               dendrogram_ratio=0.1,
               cbar_pos=(1.06,0.65,0.05,0.25)
              )
fig.ax_col_dendrogram.set_visible(False)
fig.ax_heatmap.set_yticks(ticks = fig.ax_heatmap.get_yticks(), labels = fig.ax_heatmap.get_yticklabels(), fontsize=16, fontweight = "bold")
fig.ax_heatmap.set_xticks(ticks = fig.ax_heatmap.get_xticks(), labels = '')
fig.ax_heatmap.tick_params(bottom = False)
fig.fig.suptitle("Differentially Methylated Regions: CD Adenoma vs Autopsy Derived Normal Gland", fontsize=20, fontweight='bold')
fig.savefig('methylation_heatmap.pdf', bbox_inches='tight')
# Out:
# /Users/mullaneydb/anaconda3/lib/python3.9/site-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
