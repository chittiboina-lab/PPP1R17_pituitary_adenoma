# %%
# Western + PCR from mCorts, PPP1R17
# proliferation, cell cycle
# mCort vs GFP RNAseq
# mCort total/phospho proteome
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## mCort_GFP vs mCort_PPP1R17 RNAseq heatmap

# %%
data = pd.read_csv('../../mCort_bulkRNAseq/selected.csv',index_col=0)
# data = data.dropna()
names = ['mCort_GFP rep1','mCort_GFP rep2','mCort_GFP rep3',
         'mCort_R17 rep1','mCort_R17 rep2','mCort_R17 rep3']
data.columns = names
data = data.transpose()
data
# Out:
# ID              ENSG00000187952  ENSG00000096433  ENSG00000173404  \
# mCort_GFP rep1       716.958752      4819.033026      4125.770236
# mCort_GFP rep2       764.458088      4786.000460      4364.195510
# mCort_GFP rep3       550.332480      4074.788405      3589.795279
# mCort_R17 rep1      4508.598772       708.881878       836.410426
# mCort_R17 rep2      4289.344290       703.314659       804.412868
# mCort_R17 rep3      4158.389513       560.346638       776.714156
#
# ID              ENSG00000176165  ENSG00000153048  ENSG00000128564  \
# mCort_GFP rep1      2288.982947      1989.804066      1788.085375
# mCort_GFP rep2      2364.917051      1844.353509      1734.601888
# mCort_GFP rep3      1817.551637      1481.482858      1361.539895
# mCort_R17 rep1      6945.400571       172.604425       126.327366
# mCort_R17 rep2      6784.177928       145.379960       172.454138
# mCort_R17 rep3      6265.202022       174.747873       136.146629
#
# ...

# %%
fig = sns.clustermap(data, 
               z_score = 1,
               row_cluster=True, col_cluster=True,
#                cmap=greenpurp,
#                cmap=bluepink,
               cmap='icefire',
               figsize=(16,7),
               dendrogram_ratio=0.1,
               cbar_pos=(1.06,0.65,0.05,0.25)
              )
fig.ax_col_dendrogram.set_visible(False)
fig.ax_heatmap.set_yticks(ticks = fig.ax_heatmap.get_yticks(), labels = fig.ax_heatmap.get_yticklabels(), fontsize=16, fontweight = "bold")
fig.ax_heatmap.set_xticks(ticks = fig.ax_heatmap.get_xticks(), labels = '')
fig.ax_heatmap.tick_params(bottom = False)
fig.fig.suptitle('mCort_GFP vs mCort_R17: Bulk RNAseq', fontsize=24, fontweight='bold')
fig.savefig('mcort_bulkseq.png')
# Out:
# /Users/mullaneydb/anaconda3/lib/python3.9/site-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %% [markdown]
# ## mCort_GFP vs mCort_PPP1R17 mass spec data (total and phospho proteome)

# %%
# total Proteins, horizontal
data = pd.read_csv('../../proteome_analysis/vis_data/mp_selected_total.txt', sep = '\t',index_col=0)
names = ['mCort_GFP rep1','mCort_GFP rep2','mCort_GFP rep3','mCort_GFP rep4','mCort_GFP rep5',
         'mCort_R17 rep1','mCort_R17 rep2','mCort_R17 rep3','mCort_R17 rep4','mCort_R17 rep5']
data.columns = names
data = data.transpose()
data
# Out:
#                    mp69   mp120    mp122   mp133   mp138   mp172    mp191  \
# mCort_GFP rep1  13949.1  6417.4   5366.4  3006.9  8383.0  3233.2   5041.3
# mCort_GFP rep2  13694.6  6441.1   5317.4  2959.7  7617.1  3187.1   4969.3
# mCort_GFP rep3  15108.6  7072.2   5663.3  3239.8  8700.5  3445.5   4958.3
# mCort_GFP rep4  16395.1  7470.6   5972.0  3405.0  8962.8  3571.4   5473.8
# mCort_GFP rep5  15261.7  7014.7   5573.6  3255.1  8300.9  3424.9   5326.0
# mCort_R17 rep1   8433.3  4763.2  14301.3  5748.9  6124.4  2226.4  10493.3
# mCort_R17 rep2   9611.1  5244.8  15579.5  6367.9  6549.4  2469.8  10938.8
# mCort_R17 rep3   9321.1  5161.3  14975.3  5982.3  6213.4  2385.5  10748.1
# mCort_R17 rep4   9861.4  5382.8  16009.2  6657.0  7247.7  2569.9  11401.7
# mCort_R17 rep5   9909.8  5498.8  15863.7  6551.8  6891.3  2511.2  11177.3
#
#                   mp196   mp214    mp307  ...  mp5775  mp5787  mp5900  mp6011  \
# ...

# %%
fig = sns.clustermap(data, 
               z_score = 1,
               row_cluster=True, col_cluster=True,
#                cmap=greenpurp,
#                cmap=bluepink,
               cmap='rocket',
               figsize=(16,6),
               dendrogram_ratio=0.1,
               cbar_pos=(1.06,0.65,0.05,0.25)
              )
fig.ax_col_dendrogram.set_visible(False)
fig.ax_heatmap.set_yticks(ticks = fig.ax_heatmap.get_yticks(), labels = fig.ax_heatmap.get_yticklabels(), fontsize=16, fontweight = "bold")
fig.ax_heatmap.set_xticks(ticks = fig.ax_heatmap.get_xticks(), labels = '')
fig.ax_heatmap.tick_params(bottom = False)
fig.fig.suptitle('mCort_GFP vs mCort_R17: Total Proteins', fontsize=24, fontweight='bold')
fig.savefig('mcort_total_proteins.png')

# %%
# Phospho Proteins horizontal
data = pd.read_csv('../../proteome_analysis/vis_data/mp_selected_phospho.txt', sep = '\t',index_col=0)
names = ['mCort_GFP rep1','mCort_GFP rep2','mCort_GFP rep3','mCort_GFP rep4','mCort_GFP rep5',
         'mCort_R17 rep1','mCort_R17 rep2','mCort_R17 rep3','mCort_R17 rep4','mCort_R17 rep5']
data.columns = names
data = data.transpose()
data
# Out:
#                  mp39  mp58  mp64  mp101  mp104  mp109  mp113  mp124  mp133  \
# mCort_GFP rep1  150.8  49.5  70.0  110.4   40.8  176.6   78.8   61.4   57.5
# mCort_GFP rep2  153.5  51.2  59.2  116.4   34.2  183.4   76.3   64.5   46.8
# mCort_GFP rep3  172.7  57.3  67.4  119.7   35.0  208.4   64.7   62.6   56.5
# mCort_GFP rep4  202.9  61.3  84.8  144.3   39.7  210.7   83.5   72.9   59.1
# mCort_GFP rep5  199.3  59.8  78.9  171.0   35.0  242.2   82.3   63.9   62.6
# mCort_R17 rep1  112.0  30.8  42.5   88.5   18.7  122.1  124.3   28.1   29.9
# mCort_R17 rep2  121.3  40.0  46.0   92.9   26.5  143.0  132.1   36.7   40.6
# mCort_R17 rep3  114.6  36.3  48.6   88.2   21.9  139.3  126.4   35.1   33.5
# mCort_R17 rep4  117.6  35.2  43.7   92.3   23.9  148.4  144.4   33.2   32.0
# mCort_R17 rep5  175.8  40.8  43.4  138.5   24.6  180.3  148.4   38.7   44.3
#
#                 mp158  ...  mp14048  mp14053  mp14105  mp14110  mp14146  \
# ...

# %%
fig = sns.clustermap(data, 
               z_score = 1,
               row_cluster=True, col_cluster=True,
#                cmap=bluepink,
               cmap='mako',
               figsize=(16,6),
               dendrogram_ratio=0.1,
               cbar_pos=(1.06,0.65,0.05,0.25)
              )
fig.ax_col_dendrogram.set_visible(False)
fig.ax_heatmap.set_yticks(ticks = fig.ax_heatmap.get_yticks(), labels = fig.ax_heatmap.get_yticklabels(), fontsize=16, fontweight = "bold")
fig.ax_heatmap.set_xticks(ticks = fig.ax_heatmap.get_xticks(), labels = '')
fig.ax_heatmap.tick_params(bottom = False)
fig.fig.suptitle('mCort_GFP vs mCort_R17: Phospho Proteins', fontsize=24, fontweight='bold')
fig.savefig('mcort_phospho_proteins.png')
