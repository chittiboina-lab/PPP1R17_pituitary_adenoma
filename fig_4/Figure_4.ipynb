# %%
# Western + PCR from mCorts, PPP1R17
# proliferation, cell cycle
# mCort vs GFP RNAseq
# mCort total/phospho proteome
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## CD Adenoma vs Normal mass spec data (total and phospho proteome)

# %%
# total Proteins, horizontal
data = pd.read_csv('../../proteome_analysis/vis_data/hp_selected_total.txt', sep = '\t',index_col=0)
names = ['Control 1','Adenoma 1','Control 2','Adenoma 2','Control 3','Adenoma 3']
data.columns = names
data = data.transpose()
data
# Out:
#                ANKH      HPSE      ENPP6   TMEM130     DAAM1      EDIL3  \
# Control 1  5.928791  5.843551   9.780075  9.298464  8.404877  11.708808
# Adenoma 1  5.595381  5.648850   8.719881  8.879158  7.953747  11.042099
# Control 2  6.062655  6.175992   9.584317  9.162824  8.151452  11.505964
# Adenoma 2  5.362489  5.406618   9.061039  8.694447  7.517149  11.064106
# Control 3  5.815867  6.155742  10.451360  8.834328  8.622252  11.555292
# Adenoma 3  5.069645  5.378430   8.908690  8.349810  7.891888  10.726394
#
#               TENM4       H1-3       PSAP    GPRC5B  ...     ICA1L     DYNLL1  \
# Control 1  6.857076  16.116504  12.484494  6.195356  ...  7.174087  10.737748
# Adenoma 1  6.225221  15.642258  12.118538  5.747987  ...  7.550970  11.183636
# Control 2  6.702101  15.427246  12.173759  6.166804  ...  7.487590  10.820964
# Adenoma 2  6.422012  15.251390  11.970081  5.901058  ...  7.798062  10.993242
# Control 3  6.731096  15.608248  11.962187  5.919300  ...  7.312444  10.698188
# Adenoma 3  6.013347  15.170622  11.374658  5.331157  ...  7.650115  11.150629
#
#                LAMP1       FST     SCAF4   CACNA2D1      TBCC      MAP1S  \
# Control 1  11.844798  6.638728  8.404389  11.731530  6.173820  10.065005
# Adenoma 1  12.381232  7.099112  8.849836  12.191236  6.483375  10.391901
# Control 2  11.810594  7.385427  9.083240  11.689218  6.933472  10.521275
# Adenoma 2  12.053714  7.664266  9.286309  11.860792  7.272113  10.708217
# Control 3  11.764681  7.091517  8.583751  11.707001  6.795968  10.478092
# Adenoma 3  12.028741  7.420514  8.999255  12.120351  7.212925  11.078284
#
#                 UGP2      MYH14
# Control 1  12.380261  12.993610
# Adenoma 1  12.884542  13.289781
# Control 2  12.619225  13.244609
# Adenoma 2  12.753204  13.419560
# Control 3  12.603316  13.053199
# Adenoma 3  13.046339  13.577966
#
# [6 rows x 74 columns]

# %%
fig = sns.clustermap(data, 
               z_score = 1,
               row_cluster=True, col_cluster=True,
#                cmap=greenpurp,
#                cmap=bluepink,
               cmap='rocket',
               figsize=(16,6),
               dendrogram_ratio=0.1,
               cbar_pos=(1.06,0.65,0.05,0.25)
              )
fig.ax_col_dendrogram.set_visible(False)
fig.ax_heatmap.set_yticks(ticks = fig.ax_heatmap.get_yticks(), labels = fig.ax_heatmap.get_yticklabels(), fontsize=16, fontweight = "bold")
fig.ax_heatmap.set_xticks(ticks = fig.ax_heatmap.get_xticks(), labels = '')
fig.ax_heatmap.tick_params(bottom = False)
fig.fig.suptitle('mCort_GFP vs mCort_R17: Total Proteins', fontsize=24, fontweight='bold')
fig.savefig('human_total_proteins.pdf', bbox_inches='tight')

# %%
# Phospho Proteins horizontal
data = pd.read_csv('../../proteome_analysis/vis_data/hp_selected_phospho.txt', sep = '\t',index_col=0)
names = ['Control 1','Adenoma 1','Control 2','Adenoma 2','Control 3','Adenoma 3']
data.columns = names
data = data.transpose()
data
# Out:
#                CANX    HP1BP3     HMGN3      CBX1     TRA2B     NOLC1  \
# Control 1  6.262275  7.458126  6.272143  8.365579  7.199214  7.016151
# Adenoma 1  5.283056  7.110401  4.500000  7.828720  6.158899  6.432002
# Control 2  5.269020  6.635450  5.262367  7.594015  5.359083  6.222881
# Adenoma 2  4.656100  6.289335  4.500000  7.296921  4.903968  5.499730
# Control 3  5.504719  7.081186  5.586098  7.702311  5.758745  6.266041
# Adenoma 3  4.500000  6.202121  4.500000  7.049721  4.969067  5.851666
#
#               HMGN3   HTATSF1     HMGN1   HTATSF1  ...    ZC3H18       NaN  \
# Control 1  6.571192  7.057025  7.997693  7.376628  ...  5.210176  5.219995
# Adenoma 1  4.997871  5.302327  6.407280  5.481492  ...  5.476816  5.771330
# Control 2  5.880374  6.576817  7.275893  6.468549  ...  5.303705  5.459086
# Adenoma 2  5.078128  5.522067  6.664005  5.390272  ...  5.868367  5.828749
# Control 3  5.796354  6.551088  7.122989  6.792320  ...  5.359202  5.583455
# Adenoma 3  4.863289  5.575099  6.451412  6.152471  ...  6.005615  5.907600
#
#             PRPF38B     ACIN1      PCNP     PEA15     SRRM1    BCLAF1  \
# Control 1  6.022482  5.347661  4.500000  5.564363  6.759360  6.951670
# Adenoma 1  6.628107  5.829789  4.691633  6.106770  7.096026  7.315160
# Control 2  6.472256  5.696330  5.532221  6.888114  6.902241  7.018100
# Adenoma 2  6.722202  6.009203  5.848461  7.356807  7.182122  7.190836
# Control 3  6.069884  5.225802  5.123612  6.657007  6.494827  6.686701
# Adenoma 3  6.477689  5.514053  5.660996  6.920874  7.047401  7.271246
#
#              NUCKS1     MATR3
# Control 1  6.325726  8.002579
# Adenoma 1  6.642511  8.375962
# Control 2  6.434150  8.481755
# Adenoma 2  6.984493  8.772714
# Control 3  6.626859  8.108831
# Adenoma 3  6.800490  8.755257
#
# [6 rows x 87 columns]

# %%
fig = sns.clustermap(data, 
               z_score = 1,
               row_cluster=True, col_cluster=True,
#                cmap=bluepink,
               cmap='mako',
               figsize=(16,6),
               dendrogram_ratio=0.1,
               cbar_pos=(1.06,0.65,0.05,0.25)
              )
fig.ax_col_dendrogram.set_visible(False)
fig.ax_heatmap.set_yticks(ticks = fig.ax_heatmap.get_yticks(), labels = fig.ax_heatmap.get_yticklabels(), fontsize=16, fontweight = "bold")
fig.ax_heatmap.set_xticks(ticks = fig.ax_heatmap.get_xticks(), labels = '')
fig.ax_heatmap.tick_params(bottom = False)
fig.fig.suptitle('mCort_GFP vs mCort_R17: Phospho Proteins', fontsize=24, fontweight='bold')
fig.savefig('human_phospho_proteins.pdf', bbox_inches='tight')
